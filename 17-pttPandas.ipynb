# %%
import pandas as pd
import os
import glob

# %%
path = './res_gossiping'
path_list = os.listdir(path)

# %%
path_list
# Out:
# ['[問卦] 台劇這麼尬是否因為好演員都去鄉土劇？.txt',
#  '[問卦] 小馮好漂釀.txt',
#  '[問卦] 位神ㄇ小時候很喜歡ㄉ卡通現在看很尷尬?.txt',
#  '[問卦] 盒盒手皺皺ㄉ.txt',
#  '[問卦] 日本的牙醫診所竟然比便利商店還多.txt',
#  '[問卦] 台灣長輩為何那麼愛去大陸旅遊啊?.txt',
#  '[問卦] 為什麼有人會在超商念經？.txt',
#  '[問卦] 客庄券突然刪了很多店？.txt',
#  '[問卦] 犯錯後改過自新上任更高職位有錯嗎.txt',
#  '[問卦] 日本女主播說她現在會在家裡運動.txt',
#  '[問卦] 懶叫是不是痛苦的來源.txt',
#  'Re: [問卦] ~(@[email\xa0protected])~ 波士頓是個怎樣的地方.txt',
#  '[新聞] 木冥合相第3波衝擊要來了 國師曝：我們.txt',
#  '[問卦] 有錢人眼裡的小模是？.txt',
#  '[問卦] 有沒有水電行很喜歡帶狗去工作的八卦？.txt',
#  '[新聞] 徐永明移送北檢 一路搖手說「沒有」.txt',
#  '[問卦] 青蛙蟾蜍瘋狂大叫4甚麼徵兆R?.txt',
#  '[問卦] 一大早就在超商繳費影印買咖啡什麼心態？.txt',
#  '[問卦] 女生穿緊身褲騎車是不是超性感？.txt',
#  '[問卦] 撿到古董音響 484發財了？.txt',
#  '[問卦] 為什麼8+9這麼有錢還要買外匯車.txt',
#  '[問卦] 豪宅特勤保全跟一般保全是不是差很多啊.txt',
#  '[新聞] 士兵賴床不參加早點名  被叫醒爆氣竟棒打.txt',
#  '[Live] 總統蔡英文赴故李登輝前總統緬懷追思會場致意.txt',
#  'Re: [新聞] 中国來的？日本各地收到謎之種子.txt',
#  'Re: [爆卦]新莊昌平派出所所長歡迎進來看.txt',
#  '[問卦] 欸 反應時間170ms再八卦是甚麼等級.txt',
#  '[新聞] 砸2千萬建網站、傳簡訊 農遊券最燒錢.txt',
#  '[新聞] 人事大地震 多位立委質疑廖燦昌 政治任命.txt',
#  '[問卦] 日漫輸在主角要一直變強嗎？.txt',
# ...

# %%
path_list = glob.glob('./res_gossiping/*.txt')
path_list
# Out:
# ['./res_gossiping/[問卦] 台劇這麼尬是否因為好演員都去鄉土劇？.txt',
#  './res_gossiping/[問卦] 小馮好漂釀.txt',
#  './res_gossiping/[問卦] 位神ㄇ小時候很喜歡ㄉ卡通現在看很尷尬?.txt',
#  './res_gossiping/[問卦] 盒盒手皺皺ㄉ.txt',
#  './res_gossiping/[問卦] 日本的牙醫診所竟然比便利商店還多.txt',
#  './res_gossiping/[問卦] 台灣長輩為何那麼愛去大陸旅遊啊?.txt',
#  './res_gossiping/[問卦] 為什麼有人會在超商念經？.txt',
#  './res_gossiping/[問卦] 客庄券突然刪了很多店？.txt',
#  './res_gossiping/[問卦] 犯錯後改過自新上任更高職位有錯嗎.txt',
#  './res_gossiping/[問卦] 日本女主播說她現在會在家裡運動.txt',
#  './res_gossiping/[問卦] 懶叫是不是痛苦的來源.txt',
#  './res_gossiping/Re: [問卦] ~(@[email\xa0protected])~ 波士頓是個怎樣的地方.txt',
#  './res_gossiping/[新聞] 木冥合相第3波衝擊要來了 國師曝：我們.txt',
#  './res_gossiping/[問卦] 有錢人眼裡的小模是？.txt',
#  './res_gossiping/[問卦] 有沒有水電行很喜歡帶狗去工作的八卦？.txt',
#  './res_gossiping/[新聞] 徐永明移送北檢 一路搖手說「沒有」.txt',
#  './res_gossiping/[問卦] 青蛙蟾蜍瘋狂大叫4甚麼徵兆R?.txt',
#  './res_gossiping/[問卦] 一大早就在超商繳費影印買咖啡什麼心態？.txt',
#  './res_gossiping/[問卦] 女生穿緊身褲騎車是不是超性感？.txt',
#  './res_gossiping/[問卦] 撿到古董音響 484發財了？.txt',
#  './res_gossiping/[問卦] 為什麼8+9這麼有錢還要買外匯車.txt',
# ...

# %%
data = list()
for file in path_list:
    with open(file, 'r', encoding='utf-8') as f:
        tmp_str = f.read() # whole article string
        tmp_reply = tmp_str.split('---split---')[1]
